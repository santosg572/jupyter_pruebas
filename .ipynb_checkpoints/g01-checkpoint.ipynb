# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.linspace(0, 50*np.pi, 100)

y1 = np.sin(t)

y2 = np.sin(2*t)

y3 = np.sin(t/2)

y4 = np.sin(t/4)

'''
plt.plot(t,y1)
plt.plot(t,y2, 'r')
plt.plot(t,y3, 'b')
'''
y = y1+2*y2-2*y3++3*y4

plt.plot(t,y)
